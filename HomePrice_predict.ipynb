# %%
import pandas as pd
'''
i'll have the features about one house, and with this, i'll predict how much this house cost
'''
# Out:
# "\ni'll have the features about one house, and with this, i'll predict how much this house cost\n"

# %%
home_data = pd.read_csv("train.csv")

# %%
home_data#only for see how my model works
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(house_model.SalePrice)
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y = home_data.SalePrice #preços das casas

# %%
feature_names = ["LotArea","YearBuilt","1stFlrSF","2ndFlrSF","FullBath","BedroomAbvGr","TotRmsAbvGrd"] #caracteristicas que irei pegar para o valor de X

# %%
X = home_data[feature_names]#Irei pegar somente as caracteristicas selecionaas

# %%
X
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0        8450       2003       856       854         2             3
# 1        9600       1976      1262         0         2             3
# 2       11250       2001       920       866         2             3
# 3        9550       1915       961       756         1             3
# 4       14260       2000      1145      1053         2             4
# ...       ...        ...       ...       ...       ...           ...
# 1455     7917       1999       953       694         2             3
# 1456    13175       1978      2073         0         2             3
# 1457     9042       1941      1188      1152         2             4
# 1458     9717       1950      1078         0         1             2
# 1459     9937       1965      1256         0         1             3
#
#       TotRmsAbvGrd
# 0                8
# 1                6
# 2                6
# 3                7
# 4                9
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
iwoa_model = DecisionTreeRegressor(random_state=1)

# %%
iwoa_model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
result = iwoa_model.predict(X)
